# %%
import matplotlib.pyplot as plt
from sklearn.datasets import make_regression
from sklearn.model_selection import train_test_split
import numpy as np
import pandas as pd
from perceptron import Perceptron

# %%
x, y, coef = make_regression(500,n_features=1,n_informative=1,noise=15,coef=True,random_state=0)
x = np.interp(x,(x.min(),x.max()),(0,20))
y = np.interp(y,(y.min(),y.max()),(20000,150000))
plt.scatter(x,y)
plt.title("Employees' Experience and Salary")
plt.xlabel('Experience(year)')
plt.ylabel('Salary($)')
plt.show()

# %%
df = pd.DataFrame(data={'experience':x.flatten(),'salary':y})
df['experience']= df['experience'].round(1)
df['salary'] = df['salary'].round(2)
df.head()
# Out:
#    experience     salary
# 0        12.4   99956.87
# 1        10.2   83323.31
# 2        10.5   82464.54
# 3         4.0   50790.54
# 4        15.6  130062.19

# %%
X = df['experience'].values
Y = df['salary'].values

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size=.2)
X_train = X_train.reshape(-1,1)
X_test = X_test.reshape(-1,1)
Y_train = Y_train.reshape(-1,1)
Y_test = Y_test.reshape(-1,1)
print(Y_train.shape)
# Out:
# (400, 1)

# %%
slp = Perceptron(1,.0001,50)
slp.fit(X_train, Y_train)
slp.plot_losses(X_train,Y_train, 'Employees salary and experience perceptron', 'Loss value', plot_3d=False)
